# %% [markdown]
# # Deep Learning for Knee MRI Reconstruction
# **Author:** Sri Mohan
# **Date:** April 2025 (Projected)
#
# ## Objective
# To reconstruct high-fidelity MRI images from 25% undersampled k-space data using a UNet-based CNN architecture.
#
# ## Setup
# Checking availability of GPU (MPS for Mac) and importing core libraries.
